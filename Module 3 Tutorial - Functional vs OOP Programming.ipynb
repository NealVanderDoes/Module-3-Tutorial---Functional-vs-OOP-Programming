# %%
# Sort an Array of 0s, 1s, and 2s

#{ 
 # Driver Code Starts

# } Driver Code Ends
class Solution:
    # Function to sort an array of 0s, 1s, and 2s
    def sort012(self, arr):
        # Just to be clear, this function is the only work I did for this problem; the rest was already there.
        self.arr = arr 
        arr = arr.sort()
        return arr
        

#{ 
 # Driver Code Starts.
def main():
    t = int(input().strip())  # Read the number of test cases
    ob = Solution()
    while t > 0:
        t -= 1
        arr = list(map(int,
                       input().strip().split())
                   )  # Read the array as space-separated integers
        ob.sort012(arr)  # Sort the array

        print(' '.join(map(str, arr)))  # Print the sorted array
        print("~")
if __name__ == "__main__":
    main()

# } Driver Code Ends

# Binary Search
# This solution only works for 1111/1115 tests. I looked at editorial tab and I have never seen anything like that before.
# How could I have known how to do this?
#User function template for Python

class Solution:
    def binarysearch(self, arr, k):
        # Code Here
        self.arr = arr
        self.k = k
        
        try:
            position = arr.index(k)
            return position
        
        except ValueError:
            position = ("-1")
            return position
#{ 
 # Driver Code Starts
#Initial template for Python

if __name__ == "__main__":
    t = int(input())
    for _ in range(t):
        k = int(input())
        arr = list(map(int, input().split()))
        ob = Solution()
        res = ob.binarysearch(arr, k)
        print(res)
        print("~")

# } Driver Code Ends
